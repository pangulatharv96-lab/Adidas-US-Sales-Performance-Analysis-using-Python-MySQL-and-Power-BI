# %% [markdown]
# <h1>Exploratory Analysis of Adidas US Sales Data

# %% [markdown]
# <h2>Importing Necessary Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns
import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# <h2>Loding Dataset

# %%
data=pd.read_csv(r"C:\Users\Atharv\Downloads\Copy of AdidasUSSales_a1_kit102adeed.csv")

# %%
data
# Out:
#          Retailer  Retailer_ID Invoice_Date     Region          State  \
# 0     Foot Locker    1185732.0     1/1/2020  Northeast       New York
# 1     Foot Locker    1185732.0     2/1/2020  Northeast       New York
# 2     Foot Locker    1185732.0     3/1/2020  Northeast       New York
# 3     Foot Locker    1185732.0     4/1/2020  Northeast       New York
# 4     Foot Locker    1185732.0     5/1/2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9646  Foot Locker    1185732.0    22/2/2021  Northeast  New Hampshire
# 9647  Foot Locker    1185732.0    22/2/2021  Northeast  New Hampshire
# 9648            0          0.0          NaN        NaN            NaN
# 9649            0          NaN          NaN        NaN              0
# 9650          NaN          NaN          NaN        NaN            NaN
#
#             City                    Product  Price_per_Unit  Units_Sold  \
# ...

# %% [markdown]
# <h2>Understanding The Dataset

# %% [raw]
# By offering information on product demand, revenue generation, and profitability across various regions, retailers, and sales channels, this dataset aids in our comprehension of Adidas' sales performance in the US. By examining this data, we can determine which products make up the largest portion of overall sales and operating profit, how sales differ by state and region, and which retailers are most important in generating income. Along with time-based trends that highlight peak sales periods and seasonal patterns, the dataset also shows the efficacy of various sales strategies, including online, outlet, and in-store sales. All things considered, this information facilitates data-driven decision-making by highlighting Adidas's strongest performance areas, areas for profitability improvement, and the business tactics that have the biggest effects on the US market.

# %%
data.drop_duplicates()
# Out:
#          Retailer  Retailer_ID Invoice_Date     Region          State  \
# 0     Foot Locker    1185732.0     1/1/2020  Northeast       New York
# 1     Foot Locker    1185732.0     2/1/2020  Northeast       New York
# 2     Foot Locker    1185732.0     3/1/2020  Northeast       New York
# 3     Foot Locker    1185732.0     4/1/2020  Northeast       New York
# 4     Foot Locker    1185732.0     5/1/2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9646  Foot Locker    1185732.0    22/2/2021  Northeast  New Hampshire
# 9647  Foot Locker    1185732.0    22/2/2021  Northeast  New Hampshire
# 9648            0          0.0          NaN        NaN            NaN
# 9649            0          NaN          NaN        NaN              0
# 9650          NaN          NaN          NaN        NaN            NaN
#
#             City                    Product  Price_per_Unit  Units_Sold  \
# ...

# %%
data.shape
# Out:
# (9651, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9651 entries, 0 to 9650
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9650 non-null   object
#  1   Retailer_ID       9649 non-null   float64
#  2   Invoice_Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9649 non-null   object
#  5   City              9649 non-null   object
#  6   Product           9649 non-null   object
#  7   Price_per_Unit    9649 non-null   float64
#  8   Units_Sold        9650 non-null   float64
#  9   Total_Sales       9649 non-null   float64
#  10  Operating_Profit  9649 non-null   float64
#  11  Operating_Margin  9649 non-null   float64
#  12  Sales_Method      9648 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 980.3+ KB

# %%
data.dtypes
# Out:
# Retailer             object
# Retailer_ID         float64
# Invoice_Date         object
# Region               object
# State                object
# City                 object
# Product              object
# Price_per_Unit      float64
# Units_Sold          float64
# Total_Sales         float64
# Operating_Profit    float64
# Operating_Margin    float64
# Sales_Method         object
# dtype: object

# %%
data["Invoice_Date"]=pd.to_datetime(data["Invoice_Date"],format="%d/%m/%Y",errors="coerce")

# %%
data.dtypes
# Out:
# Retailer                    object
# Retailer_ID                float64
# Invoice_Date        datetime64[ns]
# Region                      object
# State                       object
# City                        object
# Product                     object
# Price_per_Unit             float64
# Units_Sold                 float64
# Total_Sales                float64
# Operating_Profit           float64
# Operating_Margin           float64
# Sales_Method                object
# dtype: object

# %%
data.describe()
# Out:
#         Retailer_ID                   Invoice_Date  Price_per_Unit  \
# count  9.649000e+03                           9648     9649.000000
# mean   1.173728e+06  2021-05-10 15:20:44.776119296       90.413307
# min    0.000000e+00            2020-01-01 00:00:00        0.000000
# 25%    1.185732e+06            2021-02-17 00:00:00       35.000000
# 50%    1.185732e+06            2021-06-04 00:00:00       45.000000
# 75%    1.185732e+06            2021-09-16 00:00:00       55.000000
# max    1.197831e+06            2021-12-31 00:00:00   436199.000000
# std    2.894136e+04                            NaN     4440.183105
#
#          Units_Sold   Total_Sales  Operating_Profit  Operating_Margin
# count  9.650000e+03  9.649000e+03       9649.000000       9649.000000
# mean   8.158323e+02  1.865275e+05      34421.714469          0.422991
# min    0.000000e+00  0.000000e+00          0.000000          0.100000
# 25%    1.060000e+02  4.256000e+03       1922.000000          0.350000
# ...

# %%
data.head()
# Out:
#       Retailer  Retailer_ID Invoice_Date     Region     State      City  \
# 0  Foot Locker    1185732.0   2020-01-01  Northeast  New York  New York
# 1  Foot Locker    1185732.0   2020-01-02  Northeast  New York  New York
# 2  Foot Locker    1185732.0   2020-01-03  Northeast  New York  New York
# 3  Foot Locker    1185732.0   2020-01-04  Northeast  New York  New York
# 4  Foot Locker    1185732.0   2020-01-05  Northeast  New York  New York
#
#                      Product  Price_per_Unit  Units_Sold  Total_Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating_Profit  Operating_Margin Sales_Method
# 0          300000.0              0.50     In-store
# ...

# %%
data.sample()
# Out:
#        Retailer  Retailer_ID Invoice_Date     Region    State        City  \
# 3794  West Gear    1185732.0   2021-10-12  Northeast  Vermont  Burlington
#
#               Product  Price_per_Unit  Units_Sold  Total_Sales  \
# 3794  Women's Apparel            75.0       300.0     225000.0
#
#       Operating_Profit  Operating_Margin Sales_Method
# 3794           90000.0               0.4     In-store

# %%
data.tail()
# Out:
#          Retailer  Retailer_ID Invoice_Date     Region          State  \
# 9646  Foot Locker    1185732.0   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker    1185732.0   2021-02-22  Northeast  New Hampshire
# 9648            0          0.0          NaT        NaN            NaN
# 9649            0          NaN          NaT        NaN              0
# 9650          NaN          NaN          NaT        NaN            NaN
#
#             City                  Product  Price_per_Unit  Units_Sold  \
# 9646  Manchester  Men's Athletic Footwear            42.0        70.0
# 9647  Manchester  Women's Street Footwear            29.0        83.0
# 9648         NaN                      NaN        436199.0   2478861.0
# 9649         NaN                        0             NaN   2915060.0
# 9650           0                      NaN             0.0         NaN
#
#       Total_Sales  Operating_Profit  Operating_Margin Sales_Method
# ...

# %%
numeric_columns=data.select_dtypes(["int64","float64"])
numeric_columns
# Out:
#       Retailer_ID  Price_per_Unit  Units_Sold  Total_Sales  Operating_Profit  \
# 0       1185732.0            50.0      1200.0     600000.0     300000.000000
# 1       1185732.0            50.0      1000.0     500000.0     150000.000000
# 2       1185732.0            40.0      1000.0     400000.0     140000.000000
# 3       1185732.0            45.0       850.0     382500.0     133875.000000
# 4       1185732.0            60.0       900.0     540000.0     162000.000000
# ...           ...             ...         ...          ...               ...
# 9646    1185732.0            42.0        70.0       2940.0       1235.000000
# 9647    1185732.0            29.0        83.0       2407.0        650.000000
# 9648          0.0        436199.0   2478861.0  899902125.0               NaN
# 9649          NaN             NaN   2915060.0          NaN               NaN
# 9650          NaN             0.0         NaN          NaN          0.913431
#
#       Operating_Margin
# ...

# %%
numeric_columns.columns
# Out:
# Index(['Retailer_ID', 'Price_per_Unit', 'Units_Sold', 'Total_Sales',
#        'Operating_Profit', 'Operating_Margin'],
#       dtype='object')

# %%
categorical_columns=data.select_dtypes(["object"])
categorical_columns
# Out:
#          Retailer     Region          State        City  \
# 0     Foot Locker  Northeast       New York    New York
# 1     Foot Locker  Northeast       New York    New York
# 2     Foot Locker  Northeast       New York    New York
# 3     Foot Locker  Northeast       New York    New York
# 4     Foot Locker  Northeast       New York    New York
# ...           ...        ...            ...         ...
# 9646  Foot Locker  Northeast  New Hampshire  Manchester
# 9647  Foot Locker  Northeast  New Hampshire  Manchester
# 9648            0        NaN            NaN         NaN
# 9649            0        NaN              0         NaN
# 9650          NaN        NaN            NaN           0
#
#                         Product Sales_Method
# 0         Men's Street Footwear     In-store
# 1       Men's Athletic Footwear     In-store
# 2       Women's Street Footwear     In-store
# 3     Women's Athletic Footwear     In-store
# 4                 Men's Apparel     In-store
# ...

# %%
categorical_columns.columns
# Out:
# Index(['Retailer', 'Region', 'State', 'City', 'Product', 'Sales_Method'], dtype='object')

# %% [markdown]
# <h2>Checking Unique Values

# %%
data.nunique()
# Out:
# Retailer               7
# Retailer_ID            5
# Invoice_Date         724
# Region                 5
# State                 51
# City                  53
# Product                7
# Price_per_Unit        96
# Units_Sold           363
# Total_Sales         3139
# Operating_Profit    4188
# Operating_Margin      67
# Sales_Method           3
# dtype: int64

# %%
numeric_columns.nunique()
# Out:
# Retailer_ID            5
# Price_per_Unit        96
# Units_Sold           363
# Total_Sales         3139
# Operating_Profit    4188
# Operating_Margin      67
# dtype: int64

# %% [markdown]
# <h4>Retailer

# %%
categorical_columns["Retailer"].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon', '0', nan], dtype=object)

# %% [markdown]
# <h4>Region

# %%
categorical_columns['Region'].unique()
# Out:
# array(['Northeast', 'South', 'West', 'Midwest', 'Southeast', nan],
#       dtype=object)

# %% [markdown]
# <h4>State

# %%
categorical_columns['State'].unique()
# Out:
# array(['New York', 'Texas', 'California', 'Illinois', 'Pennsylvania',
#        'Nevada', 'Colorado', 'Washington', 'Florida', 'Minnesota',
#        'Montana', 'Tennessee', 'Nebraska', 'Alabama', 'Maine', 'Alaska',
#        'Hawaii', 'Wyoming', 'Virginia', 'Michigan', 'Missouri', 'Utah',
#        'Oregon', 'Louisiana', 'Idaho', 'Arizona', 'New Mexico', 'Georgia',
#        'South Carolina', 'North Carolina', 'Ohio', 'Kentucky',
#        'Mississippi', 'Arkansas', 'Oklahoma', 'Kansas', 'South Dakota',
#        'North Dakota', 'Iowa', 'Wisconsin', 'Indiana', 'West Virginia',
#        'Maryland', 'Delaware', 'New Jersey', 'Connecticut',
#        'Rhode Island', 'Massachusetts', 'Vermont', 'New Hampshire', nan,
#        '0'], dtype=object)

# %% [markdown]
# <h4>City

# %%
categorical_columns['City'].unique()
# Out:
# array(['New York', 'Houston', 'San Francisco', 'Los Angeles', 'Chicago',
#        'Dallas', 'Philadelphia', 'Las Vegas', 'Denver', 'Seattle',
#        'Miami', 'Minneapolis', 'Billings', 'Knoxville', 'Omaha',
#        'Birmingham', 'Portland', 'Anchorage', 'Honolulu', 'Orlando',
#        'Albany', 'Cheyenne', 'Richmond', 'Detroit', 'St. Louis',
#        'Salt Lake City', 'New Orleans', 'Boise', 'Phoenix', 'Albuquerque',
#        'Atlanta', 'Charleston', 'Charlotte', 'Columbus', 'Louisville',
#        'Jackson', 'Little Rock', 'Oklahoma City', 'Wichita',
#        'Sioux Falls', 'Fargo', 'Des Moines', 'Milwaukee', 'Indianapolis',
#        'Baltimore', 'Wilmington', 'Newark', 'Hartford', 'Providence',
#        'Boston', 'Burlington', 'Manchester', nan, '0'], dtype=object)

# %% [markdown]
# <h4>Product

# %%
categorical_columns['Product'].unique()
# Out:
# array(["Men's Street Footwear", "Men's Athletic Footwear",
#        "Women's Street Footwear", "Women's Athletic Footwear",
#        "Men's Apparel", "Women's Apparel", nan, '0'], dtype=object)

# %% [markdown]
# <h4>Sales_Method

# %%
categorical_columns['Sales_Method'].unique()
# Out:
# array(['In-store', 'Outlet', 'Online', nan], dtype=object)

# %% [markdown]
# <h2>Replace Categories

# %%
data["Retailer"]=data["Retailer"].replace(['0',"nan"],"Nan")

# %%
data.Retailer.unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon', 'Nan', nan], dtype=object)

# %%
data["State"]=data["State"].replace(['0',"nan"],"nan")

# %%
data.State.unique()
# Out:
# array(['New York', 'Texas', 'California', 'Illinois', 'Pennsylvania',
#        'Nevada', 'Colorado', 'Washington', 'Florida', 'Minnesota',
#        'Montana', 'Tennessee', 'Nebraska', 'Alabama', 'Maine', 'Alaska',
#        'Hawaii', 'Wyoming', 'Virginia', 'Michigan', 'Missouri', 'Utah',
#        'Oregon', 'Louisiana', 'Idaho', 'Arizona', 'New Mexico', 'Georgia',
#        'South Carolina', 'North Carolina', 'Ohio', 'Kentucky',
#        'Mississippi', 'Arkansas', 'Oklahoma', 'Kansas', 'South Dakota',
#        'North Dakota', 'Iowa', 'Wisconsin', 'Indiana', 'West Virginia',
#        'Maryland', 'Delaware', 'New Jersey', 'Connecticut',
#        'Rhode Island', 'Massachusetts', 'Vermont', 'New Hampshire', nan,
#        'nan'], dtype=object)

# %%
data["City"]=data["City"].replace(['0',"nan"],"Nan")

# %%
data.City.unique()
# Out:
# array(['New York', 'Houston', 'San Francisco', 'Los Angeles', 'Chicago',
#        'Dallas', 'Philadelphia', 'Las Vegas', 'Denver', 'Seattle',
#        'Miami', 'Minneapolis', 'Billings', 'Knoxville', 'Omaha',
#        'Birmingham', 'Portland', 'Anchorage', 'Honolulu', 'Orlando',
#        'Albany', 'Cheyenne', 'Richmond', 'Detroit', 'St. Louis',
#        'Salt Lake City', 'New Orleans', 'Boise', 'Phoenix', 'Albuquerque',
#        'Atlanta', 'Charleston', 'Charlotte', 'Columbus', 'Louisville',
#        'Jackson', 'Little Rock', 'Oklahoma City', 'Wichita',
#        'Sioux Falls', 'Fargo', 'Des Moines', 'Milwaukee', 'Indianapolis',
#        'Baltimore', 'Wilmington', 'Newark', 'Hartford', 'Providence',
#        'Boston', 'Burlington', 'Manchester', nan, 'Nan'], dtype=object)

# %%
data["Product"]=data["Product"].replace(['0',"nan"],"Nan")

# %%
data.Product.unique()
# Out:
# array(["Men's Street Footwear", "Men's Athletic Footwear",
#        "Women's Street Footwear", "Women's Athletic Footwear",
#        "Men's Apparel", "Women's Apparel", nan, 'Nan'], dtype=object)

# %% [markdown]
# <h2>Handling Null Values

# %%
data.isnull().sum()
# Out:
# Retailer            1
# Retailer_ID         2
# Invoice_Date        3
# Region              3
# State               2
# City                2
# Product             2
# Price_per_Unit      2
# Units_Sold          1
# Total_Sales         2
# Operating_Profit    2
# Operating_Margin    2
# Sales_Method        3
# dtype: int64

# %%
numeric_columns.columns
# Out:
# Index(['Retailer_ID', 'Price_per_Unit', 'Units_Sold', 'Total_Sales',
#        'Operating_Profit', 'Operating_Margin'],
#       dtype='object')

# %% [markdown]
# <h4>Handling Null Values from Int64,float64

# %% [markdown]
# <h4>Retailer_ID

# %%
 data['Retailer_ID']=data['Retailer_ID'].fillna(data['Retailer_ID'].mean())

# %%
sns.kdeplot(data['Retailer_ID'])
# Out:
# <Axes: xlabel='Retailer_ID', ylabel='Density'>

# %% [markdown]
# <h4>Price_per_Unit

# %%
 data['Price_per_Unit']=data['Price_per_Unit'].fillna(data['Price_per_Unit'].mean())

# %%
sns.kdeplot(data['Price_per_Unit'])
# Out:
# <Axes: xlabel='Price_per_Unit', ylabel='Density'>

# %% [markdown]
# <h4>Units_Sold

# %%
data['Units_Sold']=data['Units_Sold'].fillna(data['Units_Sold'].mean())

# %%
sns.kdeplot(data['Units_Sold'])
# Out:
# <Axes: xlabel='Units_Sold', ylabel='Density'>

# %% [markdown]
# <h4>Total_Sales

# %%
data['Total_Sales']=data['Total_Sales'].fillna(data['Total_Sales'].mean())

# %%
sns.kdeplot(data['Total_Sales'])
# Out:
# <Axes: xlabel='Total_Sales', ylabel='Density'>

# %% [markdown]
# <h4>Operating_Profit

# %%
data['Operating_Profit']=data['Operating_Profit'].fillna(data['Operating_Profit'].mean())

# %%
sns.kdeplot(data['Operating_Profit'])
# Out:
# <Axes: xlabel='Operating_Profit', ylabel='Density'>

# %% [markdown]
# <h4>Operating_Margin

# %%
data['Operating_Margin']=data['Operating_Margin'].fillna(data['Operating_Margin'].mean())

# %%
sns.kdeplot(data['Operating_Margin'])
# Out:
# <Axes: xlabel='Operating_Margin', ylabel='Density'>

# %%
data['Invoice_Date']=data['Invoice_Date'].fillna(data['Invoice_Date'].mean())

# %%
data.isnull().sum()
# Out:
# Retailer            1
# Retailer_ID         0
# Invoice_Date        0
# Region              3
# State               2
# City                2
# Product             2
# Price_per_Unit      0
# Units_Sold          0
# Total_Sales         0
# Operating_Profit    0
# Operating_Margin    0
# Sales_Method        3
# dtype: int64

# %%
data.select_dtypes(include='object').isnull().sum()
# Out:
# Retailer        1
# Region          3
# State           2
# City            2
# Product         2
# Sales_Method    3
# dtype: int64

# %%
data['Retailer'] = data['Retailer'].fillna('Unknown')

# %%
data['Region'] = data['Region'].fillna('Unknown')

# %%
data['Product'] = data['Product'].fillna('Unknown')

# %%
data['State'] = data['State'].fillna('Unknown')

# %%
data['City'] = data['City'].fillna('Unknown')

# %%
data['Sales_Method'] = data['Sales_Method'].fillna('Unknown')

# %%
data.isnull().sum()
# Out:
# Retailer            0
# Retailer_ID         0
# Invoice_Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price_per_Unit      0
# Units_Sold          0
# Total_Sales         0
# Operating_Profit    0
# Operating_Margin    0
# Sales_Method        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.groupby('Retailer')['Total_Sales'].sum().sort_values(ascending=False).head(1)
data.groupby('Retailer')['Total_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Retailer'>

# %%
data.groupby('City')['Total_Sales'].sum().sort_values(ascending=False).head(10)
data.groupby('City')['Total_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='line')
# Out:
# <Axes: xlabel='City'>

# %%
data.groupby('City')['Total_Sales'].sum().sort_values(ascending=False).head(10)
data.groupby('City')['Total_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
data.groupby('Product')['Total_Sales'].sum().sort_values(ascending=False).head(10)
data.groupby('Product')['Total_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='Product'>

# %%
data.groupby('Product')['Total_Sales'].sum().sort_values(ascending=False).head(10)
data.groupby('Product')['Total_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# <h2>Transfer Data Python to my sql

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as connector
import pandas as pd

# %%
pip install pymysql sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("atharv@5104")
host = "localhost"
port = "3306"
database = "Adidas_sales"   # 🔥 must exist

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

engine.connect()
print("MySQL connected successfully")

data.to_sql("customer", engine, if_exists="replace", index=False)
print("Table created successfully")
# Out:
# MySQL connected successfully
# Table created successfully
